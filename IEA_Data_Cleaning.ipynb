# %% [markdown]
# # IEA CCUS Projects

# %% [markdown]
# ### Data Dictionary
#
# | Category | Subcategory | Description |
# |----------|-------------|-------------|
# | **Project type** | | |
# | | Full chain | Projects where CO2 is transported from one capture facility to one injection site, typically involving a single operator. |
# | | Capture | Capture-only project (project does not include any transport and storage development but can be developed as part of a CCUS hub). |
# | | Transport | CO2 transport-only project, which may include CO2 shipping, pipelines, terminals with liquefaction stations/buffer storage, etc. |
# | | Storage | CO2 storage-only project (no mention of connecting infrastructure), including both dedicated storage and CO2 enhanced oil recovery (EOR). |
# | | T&S | CO2 transport and storage project which includes both transport and storage development. |
# | | CCU | A project that captures CO2 for use (excluding internal use such as urea production) with significant climate benefits and a clearly identified source for the captured CO2. |
# | **Dates** | | |
# | | Announcement | Year of project announcement. |
# | | FID | Actual or planned year of final investment decision (FID). |
# | | Operation | Actual or planned year of project commissioning. |
# | | Suspension/decommissioning | Actual year of suspension/decommissioning. |
# | **Project status** | | |
# | | Planned | Project at concept, feasibility or engineering study (FEED) stage. Concept projects include announcements with little to no further information available (e.g. capture technology, site, stakeholders, budget, timeline). |
# | | Under construction | A final investment decision (FID) has been announced and construction is ongoing or imminent. |
# | | Operational | Project has been commissioned and is running. |
# | | Suspended | Project operation is suspended for more than six months. |
# | | Decommissioned | Project operation is permanently stopped. |
# | **Project Phase** | | If projects have defined announced phases or plan to develop capacity in a stepwise manner, this column is used. Phasing starts from 1. Announced capacity across phases is additional, not cumulative. |
# | **Announced capacity (Mt CO2 per year)** | | Announced or actual capture, transport and/or storage CO2 capacity, in Mt CO2 per year. When capture capacity is announced as a range, or several values are available, announced capacity is entered as a range. |
# | **Estimated capacity by IEA (Mt CO2 per year)** | | Estimated capture capacity based on other plant details (e.g. fuel production capacity) or potential deployment plans. See conversion factors for further assumptions. |
# | **Sector** | | These sector categories will be published in the online version. For capture, full chain, and CCU projects, the sector corresponds to the source of capture. |
# | | Power and heat | Capture, full chain, and CCU projects which capture CO2 from power and heat facilities (includes waste-to-energy plants). |
# | | Natural gas processing/LNG | Capture, full chain, and CCU projects which capture CO2 from natural gas processing and liquefied natural gas (LNG) trains. |
# | | Biofuels | Capture, full chain, and CCU projects which capture CO2 from bioethanol, biodiesel, and biogas facilities. |
# | | Hydrogen/ammonia | Capture, full chain, and CCU projects which capture CO2 from off-site hydrogen and ammonia production. When CO2 is captured on a hydrogen production plant for on-site use (e.g. iron and steel, refinery, fertiliser), the sector is tagged as the main application. |
# | | Other fuel transformation | Capture, full chain, and CCU projects which capture CO2 from other fuel transformation facilities including refineries, coal-to-gas, coal-to-liquids, and gas-to-liquids plants. |
# | | Cement | Capture, full chain, and CCU projects which capture CO2 from cement and lime facilities. |
# | | Iron and steel | Capture, full chain, and CCU projects which capture CO2 from iron and steel plants. |
# | | Chemicals | Capture, full chain, and CCU projects which capture CO2 from chemical and fertiliser plants. |
# | | Other industry | Capture, full chain, and CCU projects which capture CO2 from other industrial facilities including aluminium smelters, pulp and paper mills, etc. |
# | | DAC | Direct air capture plant. |
# | | Transport | CO2 transport project. |
# | | Storage | CO2 storage project. |
# | | T&S | CO2 transport and storage project. |
# | **Fate of carbon** | | |
# | | Dedicated storage | CO2 is injected deep underground and stored permanently in a dedicated storage site. |
# | | EOR | CO2 is used for enhanced oil recovery. |
# | | Use | CO2 is used in a product with significant climate benefits. Internal use (e.g. CO2 capture and use in urea production) is excluded. |
# | | Unknown/unspecified | Fate of carbon has not been communicated. |
# | **Part of CCUS hub** | | If a capture, transport or storage project is developed as part of a CCUS hub (capture facilities connected to a network of CO2 storage sites by shared transport infrastructure), the name of the corresponding hub is indicated. |
# | **Total capture capacity (Mt CO2 per year)** | | sum (Estimated capacity) for full chain (''Full chain''), capture (''Capture'') and utilisation ("CCU") projects across phases, excluding suspended and decommissioned projects. |
# | **Total storage capacity (Mt CO2 per year)** | | sum (Estimated capacity) for full chain (''Full chain''), transport and storage (''T&S''), and storage (''Storage'') projects across phases, excluding suspended and decommissioned projects. |
# | **Number of capture facilities** | | count full chain (''Full chain''), capture (''Capture''), and utilisation ("CCU") projects excluding phases 2, 3, and 4, and suspended and decommissioned projects. |
# | **Important note on transport** | | transport capacity of individual projects is not cumulative and cannot be summed. |
# | **Conversion factors** | | For projects when CO2 captured capacity is not provided but other details are provided e.g. fuel production capacity (hydrogen, ammonia, e-fuel), captured capacity can be estimated by IEA using the following assumptions: |
# | | CO₂ emissions of natural gas fuelled hydrogen plants | 0.9105 kg CO₂/nm³ H₂. Source: California Air Resources Board, 2018. |
# | | CO₂ emissions of coal fuelled hydrogen plants | 1.9075 kg CO₂/nm³ H₂. Source: Orhan and Alper, 2014; adjusted for hydrogen production only. |
# | | Specific H2 requirement for NH3 (t/t) | 0.180072; Conversion losses 2%. |
# | | H2 density in standard conditions | 0.089 kg/m3. |

# %% [markdown]
# ### Importing Libraries for Data Analysis and Visualization
# In this section, we import Matplotlib and Seaborn, which are essential libraries for data visualization in Python. These libraries allow us to create informative plots to explore and understand the dataset better, particularly useful for identifying trends, patterns, and anomalies in the CCUS projects data.

# %%
#importing the libraries
import numpy as np
import pandas as pd
import xlrd

# %%
#loading the data
df = pd.read_excel('IEA.xlsx')
df.head()
# Out:
#                                         Project name    ID        Country  \
# 0  3D DMX ArcelorMittal and IFPEN Dunkirk (full-s...     1         France
# 1     3D DMX ArcelorMittal and IFPEN Dunkirk 'REUZE'   751         France
# 2                            7 Blue Ammonia Facility  1055          Qatar
# 3                             8Rivers H2 (8RH2) (WY)     3  United States
# 4                                     Abadi CCS/CCUS   227      Indonesia
#
#                                             Partners Project type  \
# 0  ArcelorMittal, ifp, Axens, Uetikon, Grassco, b...      Capture
# 1                     ArcelorMittal, Engie, Infinium          CCU
# 2  QAFCO, thyssenkrupp Uhde/Consolidated Contract...   Full Chain
# 3                  8Rivers, Wyoming Energy Authority      Capture
# 4  Inpex Masela 65%, Shell (trying to find a buye...   Full chain
#
#    Announcement     FID  Operation  Suspension/decommissioning  \
# ...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Checking Dataset Dimensions
# We use this step to verify the shape of the dataset after dropping columns. This ensures that the intended changes were applied successfully, and we have a clear understanding of the remaining data structure.

# %%
#checking the shape of the data
df.shape
# Out:
# (844, 31)

# %%
#checking the data variables info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Project name                           844 non-null    object
#  1   ID                                     844 non-null    int64
#  2   Country                                844 non-null    object
#  3   Partners                               844 non-null    object
#  4   Project type                           844 non-null    object
#  5   Announcement                           824 non-null    float64
#  6   FID                                    255 non-null    float64
#  7   Operation                              553 non-null    float64
#  8   Suspension/decommissioning             6 non-null      float64
#  9   Project Status                         844 non-null    object
# ...

# %% [markdown]
# ### Checking Null Values Percentage
# This step calculates the percentage of missing values in each column of the dataset. Understanding the extent of missing data is crucial for determining whether to remove, impute, or keep null values. If the percentage of missing data is too high, it might affect the quality of analysis or model predictions.

# %%
#checking for null value percentage
df.isnull().mean()*100
# Out:
# Project name                              0.000000
# ID                                        0.000000
# Country                                   0.000000
# Partners                                  0.000000
# Project type                              0.000000
# Announcement                              2.369668
# FID                                      69.786730
# Operation                                34.478673
# Suspension/decommissioning               99.289100
# Project Status                            0.000000
# Project phase                            78.672986
# Announced capacity (Mt CO2/yr)           27.251185
# Estimated capacity by IEA (Mt CO2/yr)    23.578199
# Sector                                    0.000000
# Fate of carbon                            0.000000
# Part of CCUS hub                         44.786730
# Region                                    0.000000
# Ref 1                                     4.739336
# ...

# %% [markdown]
# Removing the columns where null value percentage is more than 85%.

# %% [markdown]
# ### Checking Null Values Percentage
# This step calculates the percentage of missing values in each column of the dataset. Understanding the extent of missing data is crucial for determining whether to remove, impute, or keep null values. If the percentage of missing data is too high, it might affect the quality of analysis or model predictions.

# %%
#dropping the columns with more than 85% null values
columns = df.columns[df.isnull().mean() > 0.85]
df = df.drop(columns, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Project name                           844 non-null    object
#  1   ID                                     844 non-null    int64
#  2   Country                                844 non-null    object
#  3   Partners                               844 non-null    object
#  4   Project type                           844 non-null    object
#  5   Announcement                           824 non-null    float64
#  6   FID                                    255 non-null    float64
#  7   Operation                              553 non-null    float64
#  8   Project Status                         844 non-null    object
#  9   Project phase                          180 non-null    float64
# ...

# %% [markdown]
# Removing the columns which are not useful for analysis - columns - Ref 1, Ref 2, Ref 3, Link 1, Link 2, Link 3

# %%
#removng the columsn Ref 1, Ref 2, Ref 3, Link 1, Link 2, Link 3
df = df.drop(['Ref 1', 'Ref 2', 'Ref 3', 'Link 1', 'Link 2', 'Link 3'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Project name                           844 non-null    object
#  1   ID                                     844 non-null    int64
#  2   Country                                844 non-null    object
#  3   Partners                               844 non-null    object
#  4   Project type                           844 non-null    object
#  5   Announcement                           824 non-null    float64
#  6   FID                                    255 non-null    float64
#  7   Operation                              553 non-null    float64
#  8   Project Status                         844 non-null    object
#  9   Project phase                          180 non-null    float64
# ...

# %%
#type casting Announced capacity (Mt CO2/yr) to float and where the value is in the format like 1.3 - 1.5, we are taking the average of the range. so first search through the column and find such values and replace them with the average of the range
for i in df['Announced capacity (Mt CO2/yr)']:
    if '-' in str(i):
        a = i.split('-')
        df['Announced capacity (Mt CO2/yr)'] = df['Announced capacity (Mt CO2/yr)'].replace(i, (float(a[0])+float(a[1]))/2)
    else:
        df['Announced capacity (Mt CO2/yr)'] = df['Announced capacity (Mt CO2/yr)'].replace(i, float(i))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10868\1128477687.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Announced capacity (Mt CO2/yr)'] = df['Announced capacity (Mt CO2/yr)'].replace(i, (float(a[0])+float(a[1]))/2)

# %%
df.dtypes
# Out:
# Project name                              object
# ID                                         int64
# Country                                   object
# Partners                                  object
# Project type                              object
# Announcement                             float64
# FID                                      float64
# Operation                                float64
# Project Status                            object
# Project phase                            float64
# Announced capacity (Mt CO2/yr)           float64
# Estimated capacity by IEA (Mt CO2/yr)    float64
# Sector                                    object
# Fate of carbon                            object
# Part of CCUS hub                          object
# Region                                    object
# dtype: object

# %%
#checking for the nunique values in the data
df.nunique()
# Out:
# Project name                             841
# ID                                       841
# Country                                   66
# Partners                                 684
# Project type                               7
# Announcement                              24
# FID                                       23
# Operation                                 40
# Project Status                             4
# Project phase                              4
# Announced capacity (Mt CO2/yr)           177
# Estimated capacity by IEA (Mt CO2/yr)    185
# Sector                                    13
# Fate of carbon                             5
# Part of CCUS hub                         213
# Region                                    10
# dtype: int64

# %% [markdown]
# Removing the identifier columns - Project ID, I won't remove the project name as it could be useful in the eda.

# %%
#removing the column ID
df = df.drop(['ID'], axis=1)

# %%
df.head()
# Out:
#                                         Project name        Country  \
# 0  3D DMX ArcelorMittal and IFPEN Dunkirk (full-s...         France
# 1     3D DMX ArcelorMittal and IFPEN Dunkirk 'REUZE'         France
# 2                            7 Blue Ammonia Facility          Qatar
# 3                             8Rivers H2 (8RH2) (WY)  United States
# 4                                     Abadi CCS/CCUS      Indonesia
#
#                                             Partners Project type  \
# 0  ArcelorMittal, ifp, Axens, Uetikon, Grassco, b...      Capture
# 1                     ArcelorMittal, Engie, Infinium          CCU
# 2  QAFCO, thyssenkrupp Uhde/Consolidated Contract...   Full Chain
# 3                  8Rivers, Wyoming Energy Authority      Capture
# 4  Inpex Masela 65%, Shell (trying to find a buye...   Full chain
#
#    Announcement     FID  Operation      Project Status  Project phase  \
# 0        2019.0     NaN     2025.0             Planned            2.0
# ...

# %% [markdown]
# ### Checking Null Values Percentage
# This step calculates the percentage of missing values in each column of the dataset. Understanding the extent of missing data is crucial for determining whether to remove, impute, or keep null values. If the percentage of missing data is too high, it might affect the quality of analysis or model predictions.

# %%
#rechecking the null value percentage
df.isnull().mean()*100
# Out:
# Project name                              0.000000
# Country                                   0.000000
# Partners                                  0.000000
# Project type                              0.000000
# Announcement                              2.369668
# FID                                      69.786730
# Operation                                34.478673
# Project Status                            0.000000
# Project phase                            78.672986
# Announced capacity (Mt CO2/yr)           27.251185
# Estimated capacity by IEA (Mt CO2/yr)    23.578199
# Sector                                    0.000000
# Fate of carbon                            0.000000
# Part of CCUS hub                         44.786730
# Region                                    0.000000
# dtype: float64

# %% [markdown]
# Here two columns FID - Final Invertment Decision and Project Phase have 70% aand 78% missing values respectively. I will remove these columns as well. Although these columns could be useful but due to large missing values, I will remove these columns.

# %% [markdown]
# ### Removing Columns with High Missing Values
# In this part, we remove columns that have a significant amount of missing data. Specifically, the columns 'FID' (Final Investment Decision) and 'Project Phase' are removed due to having over 70% missing values. Keeping these columns could introduce noise and inaccuracies, so they are dropped to maintain data quality.

# %%
#removing the columns FID, Project Phase
df = df.drop(['FID', 'Project phase'], axis=1)

# %% [markdown]
# ### Checking Dataset Dimensions
# We use this step to verify the shape of the dataset after dropping columns. This ensures that the intended changes were applied successfully, and we have a clear understanding of the remaining data structure.

# %%
df.shape
# Out:
# (844, 13)

# %%
df.head()
# Out:
#                                         Project name        Country  \
# 0  3D DMX ArcelorMittal and IFPEN Dunkirk (full-s...         France
# 1     3D DMX ArcelorMittal and IFPEN Dunkirk 'REUZE'         France
# 2                            7 Blue Ammonia Facility          Qatar
# 3                             8Rivers H2 (8RH2) (WY)  United States
# 4                                     Abadi CCS/CCUS      Indonesia
#
#                                             Partners Project type  \
# 0  ArcelorMittal, ifp, Axens, Uetikon, Grassco, b...      Capture
# 1                     ArcelorMittal, Engie, Infinium          CCU
# 2  QAFCO, thyssenkrupp Uhde/Consolidated Contract...   Full Chain
# 3                  8Rivers, Wyoming Energy Authority      Capture
# 4  Inpex Masela 65%, Shell (trying to find a buye...   Full chain
#
#    Announcement  Operation      Project Status  \
# 0        2019.0     2025.0             Planned
# 1        2022.0     2025.0             Planned
# ...

# %% [markdown]
# This current form still has null values in some columns and if i try to remove the null reocrds, then we would end up losing more 60% of the data. So, I will keep the null values as it is.

# %% [markdown]
# #### Descriptive statistics

# %% [markdown]
# ### Descriptive Statistics
# This step provides summary statistics for the dataset, such as count, mean, standard deviation, min, and max for numerical columns. Descriptive statistics give us a sense of the data distribution and help identify any anomalies or outliers that may need attention.

# %%
df.describe()
# Out:
#        Announcement    Operation  Announced capacity (Mt CO2/yr)  \
# count    824.000000   553.000000                      614.000000
# mean    2020.822816  2026.175407                        3.389782
# std        3.667554     6.036721                       11.885486
# min     1982.000000  1972.000000                        0.000000
# 25%     2021.000000  2025.000000                        0.400000
# 50%     2022.000000  2027.000000                        1.200000
# 75%     2023.000000  2029.000000                        3.000000
# max     2024.000000  2040.000000                      250.000000
#
#        Estimated capacity by IEA (Mt CO2/yr)
# count                             645.000000
# mean                                3.449963
# std                                11.767173
# min                                 0.001000
# 25%                                 0.400000
# 50%                                 1.300000
# 75%                                 3.000000
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Importing Libraries for Data Analysis and Visualization
# In this section, we import Matplotlib and Seaborn, which are essential libraries for data visualization in Python. These libraries allow us to create informative plots to explore and understand the dataset better, particularly useful for identifying trends, patterns, and anomalies in the CCUS projects data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt, fig = plt.subplots(2,2,figsize=(20, 20))

#country plot
sns.countplot(df['Country'], ax=fig[0,0]).set_title('Country')

#region plot
sns.countplot(df['Region'], ax=fig[0,1]).set_title('Region')

#project type plot
sns.countplot(df['Project type'], ax=fig[1,0]).set_title('Project type')

#Annocement distribution plot
sns.barplot(x=df['Announcement'].value_counts().index, y=df['Announcement'].value_counts().values, ax=fig[1,1]).set_title('Announcement year')
# Out:
# Text(0.5, 1.0, 'Announcement year')

# %% [markdown]
# ### Importing Libraries for Data Analysis and Visualization
# In this section, we import Matplotlib and Seaborn, which are essential libraries for data visualization in Python. These libraries allow us to create informative plots to explore and understand the dataset better, particularly useful for identifying trends, patterns, and anomalies in the CCUS projects data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt, fig = plt.subplots(2,2,figsize=(20, 20))
#status plot
sns.countplot(df['Project Status'], ax=fig[0,0]).set_title('Project Status')

#announced capacity plot
sns.distplot(df['Announced capacity (Mt CO2/yr)'], ax=fig[0,1]).set_title('Announced capacity (Mt CO2/yr)')

#estimated capacity plot
sns.distplot(df['Estimated capacity by IEA (Mt CO2/yr)'], ax=fig[1,0]).set_title('Estimated capacity by IEA (Mt CO2/yr)')

#sector plot
sns.countplot(df['Sector'], ax=fig[1,1]).set_title('Sector')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10868\1816382441.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Announced capacity (Mt CO2/yr)'], ax=fig[0,1]).set_title('Announced capacity (Mt CO2/yr)')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10868\1816382441.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### Saving the Cleaned Dataset
# In this step, we save the cleaned version of the dataset as a CSV file named 'IEA_cleaned.csv'. This cleaned dataset is prepared for further analysis or model training, ensuring that we work with data that has minimal noise and is well-structured for subsequent tasks.

# %%
#SAVING THE CLEANED DATA
df.to_csv('IEA_cleaned.csv', index=False)
